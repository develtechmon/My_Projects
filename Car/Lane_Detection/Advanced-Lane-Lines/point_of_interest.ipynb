# %%
import matplotlib.pylab as plt
import cv2
import numpy as np

# %%
image = cv2.imread(r"C:\Users\jlukas\Desktop\My Projects\My Project\Lane_Detection\Advanced-Lane-Lines\test_images\challenge_video_frame_2.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.show()
